# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\YOGMAYA\\Desktop\\Datasset\\Coffee.csv')

# %%
df
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3         303.0  40909  Central  Major Market          Green Tea       Leaves
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4243      206.0  41609     West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609     West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
# 4247      206.0  41609     West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
df.head(45)
df.tail(9)
# Out:
#       Area Code   Date Market   Market Size            Product Product Line  \
# 4239      253.0  41609   West  Small Market          Earl Grey       Leaves
# 4240      509.0  41609   West  Small Market          Green Tea       Leaves
# 4241      253.0  41609   West  Small Market          Chamomile       Leaves
# 4242      425.0  41609   West  Small Market              Lemon       Leaves
# 4243      206.0  41609   West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609   West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609   West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609   West  Small Market          Colombian        Beans
# 4247      206.0  41609   West  Small Market  Decaf Irish Cream        Beans
#
#      Product Type       State     Type  Budget COGS  Budget Margin  \
# 4239          Tea  Washington  Regular           30             40
# 4240          Tea  Washington  Regular           40             50
# ...

# %%
df.sample(6)
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 885       719.0  41061  Central  Major Market         Darjeeling       Leaves
# 624       985.0  41000    South  Small Market        Caffe Latte        Beans
# 1391      702.0  41122     West  Small Market  Decaf Irish Cream        Beans
# 682       775.0  41000     West  Small Market              Lemon       Leaves
# 2581      505.0  41334    South  Small Market  Decaf Irish Cream        Beans
# 2805      702.0  41365     West  Small Market          Green Tea       Leaves
#
#      Product Type       State     Type  Budget COGS  Budget Margin  \
# 885           Tea    Colorado  Regular           40             60
# 624      Espresso   Louisiana  Regular           50             70
# 1391       Coffee      Nevada    Decaf           50             60
# 682    Herbal Tea      Nevada    Decaf          160            240
# 2581       Coffee  New Mexico    Decaf          110             20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248 entries, 0 to 4247
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Area Code       4247 non-null   float64
#  1   Date            4248 non-null   int64
#  2   Market          4248 non-null   object
#  3   Market Size     4248 non-null   object
#  4   Product         4248 non-null   object
#  5   Product Line    4248 non-null   object
#  6   Product Type    4248 non-null   object
#  7   State           4248 non-null   object
#  8   Type            4248 non-null   object
#  9   Budget COGS     4248 non-null   int64
#  10  Budget Margin   4248 non-null   int64
#  11  Budget Profit   4248 non-null   int64
#  12  Budget Sales    4248 non-null   int64
#  13  COGS            4248 non-null   int64
#  14  Inventory       4248 non-null   int64
#  15  Margin          4248 non-null   int64
#  16  Marketing       4248 non-null   int64
# ...

# %%
df.describe()
# Out:
#          Area Code          Date  Budget COGS  Budget Margin  Budget Profit  \
# count  4247.000000   4248.000000  4248.000000    4248.000000    4248.000000
# mean    582.245821  41258.916667    74.830508     100.819209      60.913371
# std     221.156394    210.712945    66.238145      92.602725      79.546123
# min     203.000000  40909.000000     0.000000    -210.000000    -320.000000
# 25%     417.000000  41083.500000    30.000000      50.000000      20.000000
# 50%     573.000000  41259.500000    50.000000      70.000000      40.000000
# 75%     772.000000  41433.500000    90.000000     130.000000      80.000000
# max     985.000000  41609.000000   450.000000     690.000000     560.000000
#
#        Budget Sales         COGS    Inventory       Margin    Marketing  \
# count   4248.000000  4248.000000  4248.000000  4248.000000  4248.000000
# mean     175.649718    84.433145   749.381356   104.293315    31.185028
# ...

# %%
df.corr()
# Out:
# C:\Users\YOGMAYA\AppData\Local\Temp\ipykernel_7684\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 Area Code      Date  Budget COGS  Budget Margin  \
# Area Code        1.000000 -0.002844     0.063690       0.022827
# Date            -0.002844  1.000000     0.004064       0.001281
# Budget COGS      0.063690  0.004064     1.000000       0.750422
# Budget Margin    0.022827  0.001281     0.750422       1.000000
# Budget Profit    0.011923  0.003722     0.579176       0.949637
# Budget Sales     0.042531  0.002604     0.911598       0.955792
# COGS             0.080464  0.007232     0.947762       0.688587
# Inventory        0.067995  0.047917     0.579876       0.119373
# Margin           0.029240  0.006306     0.680549       0.963460
# ...

# %%
df.isnull()
# Out:
#       Area Code   Date  Market  Market Size  Product  Product Line  \
# 0          True  False   False        False    False         False
# 1         False  False   False        False    False         False
# 2         False  False   False        False    False         False
# 3         False  False   False        False    False         False
# 4         False  False   False        False    False         False
# ...         ...    ...     ...          ...      ...           ...
# 4243      False  False   False        False    False         False
# 4244      False  False   False        False    False         False
# 4245      False  False   False        False    False         False
# 4246      False  False   False        False    False         False
# 4247      False  False   False        False    False         False
#
#       Product Type  State   Type  Budget COGS  Budget Margin  Budget Profit  \
# 0            False  False  False        False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# Area Code         1
# Date              0
# Market            0
# Market Size       0
# Product           0
# Product Line      0
# Product Type      0
# State             0
# Type              0
# Budget COGS       0
# Budget Margin     0
# Budget Profit     0
# Budget Sales      0
# COGS              0
# Inventory         0
# Margin            0
# Marketing         0
# Profit            0
# Sales             0
# Total Expenses    0
# dtype: int64

# %%
df['Sales']
# Out:
# 0       219
# 1       190
# 2       234
# 3       100
# 4       134
#        ...
# 4243     60
# 4244    155
# 4245    188
# 4246    188
# 4247    266
# Name: Sales, Length: 4248, dtype: int64

# %%
df[['Sales','Margin','Area Code']]
# Out:
#       Sales  Margin  Area Code
# 0       219     130        NaN
# 1       190     107      970.0
# 2       234     139      970.0
# 3       100      56      303.0
# 4       134      80      303.0
# ...     ...     ...        ...
# 4243     60      32      206.0
# 4244    155      80      509.0
# 4245    188      96      360.0
# 4246    188     104      360.0
# 4247    266     145      206.0
#
# [4248 rows x 3 columns]

# %%
df['Sales'].unique()
# Out:
# array([219, 190, 234, 100, 134, 180, 341, 150, 140, 130, 345, 546, 456,
#         45,  62,  54,  43, 170,  76, 123, 114,  90,  99,  82,  65, 200,
#         80, 210, 120, 110,  81,  94, 310, 126, 494,  93, 490,  61, 678,
#        483, 112,  85, 452, 250, 145, 118,  17, 160, 243, 232, 189, 340,
#        129, 132, 136, 354, 254, 545, 457,  63,  47, 534, 193, 165,  74,
#        103, 104, 102,  68, 128, 206,  56, 220, 137, 155, 154, 174, 115,
#         66, 325, 470, 101, 580, 645, 495, 465, 290, 122,  23, 142, 213,
#         98, 198, 125, 135, 367, 267, 567, 478,  41, 163,  75, 121, 107,
#        106, 214,  53,  79, 227, 188, 167, 124, 309, 492, 119, 523, 675,
#        513, 182, 467, 298, 127,  32,  92, 149, 223, 178, 138, 245, 587,
#        301, 578,  49,  88, 133, 222, 151, 195, 292, 117, 519, 564, 712,
#        638,  86, 159,  26,  87, 169, 256, 612, 521, 312, 589,  52, 109,
#         97, 173, 148, 235, 273,  71, 221, 204,  57, 113, 275,  89, 551,
# ...

# %%
df['Sales'].nunique()
# Out:
# 432

# %%
df['Sales'].value_counts()
# Out:
# 43     52
# 114    52
# 129    46
# 109    45
# 150    45
#        ..
# 31      1
# 657     1
# 747     1
# 24      1
# 33      1
# Name: Sales, Length: 432, dtype: int64

# %%
df['Sales'].value_counts().sort_values()
# Out:
# 33      1
# 659     1
# 519     1
# 638     1
# 551     1
#        ..
# 150    45
# 109    45
# 129    46
# 114    52
# 43     52
# Name: Sales, Length: 432, dtype: int64

# %%
df.dropna()
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3         303.0  40909  Central  Major Market          Green Tea       Leaves
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# 5         720.0  40909  Central  Major Market     Decaf Espresso        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4243      206.0  41609     West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609     West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
# 4247      206.0  41609     West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
df.drop('Area Code')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.drop('Area Code')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df.ffill()
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3         303.0  40909  Central  Major Market          Green Tea       Leaves
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4243      206.0  41609     West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609     West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
# 4247      206.0  41609     West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
df.bfill()
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0         970.0  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3         303.0  40909  Central  Major Market          Green Tea       Leaves
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4243      206.0  41609     West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609     West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
# 4247      206.0  41609     West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.size
# Out:
# 84960

# %%
df.shape
# Out:
# (4248, 20)

# %%
df.iloc[0:1000]
# Out:
#      Area Code   Date   Market   Market Size            Product Product Line  \
# 0          NaN  40909  Central  Major Market           Amaretto        Beans
# 1        970.0  40909  Central  Major Market          Colombian        Beans
# 2        970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3        303.0  40909  Central  Major Market          Green Tea       Leaves
# 4        303.0  40909  Central  Major Market        Caffe Mocha        Beans
# ..         ...    ...      ...           ...                ...          ...
# 995      918.0  41061    South  Small Market          Chamomile       Leaves
# 996      580.0  41061    South  Small Market              Lemon       Leaves
# 997      918.0  41061    South  Small Market          Colombian        Beans
# 998      405.0  41061    South  Small Market  Decaf Irish Cream        Beans
# 999      469.0  41061    South  Major Market     Decaf Espresso        Beans
#
# ...

# %%
df.groupby('Market')['Profit'].count()
# Out:
# Market
# Central    1344
# East        888
# South       672
# West       1344
# Name: Profit, dtype: int64

# %%
m = pd.Series(df.Market)
m
# Out:
# 0       Central
# 1       Central
# 2       Central
# 3       Central
# 4       Central
#          ...
# 4243       West
# 4244       West
# 4245       West
# 4246       West
# 4247       West
# Name: Market, Length: 4248, dtype: object

# %%
x=pd.DataFrame(df.Market,df.Profit)
x
# Out:
#          Market
# Profit
# 94        South
# 68         East
# 101       South
# 30      Central
# 54      Central
# ...         ...
# 19      Central
# 34      Central
# 76         East
# 86         East
# 30      Central
#
# [4248 rows x 1 columns]

# %%
df[['Market','State']].sort_values(by='Market',ascending=False)
# Out:
#        Market       State
# 4247     West  Washington
# 1047     West      Oregon
# 1045     West      Oregon
# 1044     West      Oregon
# 1043     West      Oregon
# ...       ...         ...
# 2136  Central    Illinois
# 2135  Central    Illinois
# 2134  Central    Colorado
# 2133  Central    Colorado
# 2124  Central    Colorado
#
# [4248 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248 entries, 0 to 4247
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Area Code       4247 non-null   float64
#  1   Date            4248 non-null   int64
#  2   Market          4248 non-null   object
#  3   Market Size     4248 non-null   object
#  4   Product         4248 non-null   object
#  5   Product Line    4248 non-null   object
#  6   Product Type    4248 non-null   object
#  7   State           4248 non-null   object
#  8   Type            4248 non-null   object
#  9   Budget COGS     4248 non-null   int64
#  10  Budget Margin   4248 non-null   int64
#  11  Budget Profit   4248 non-null   int64
#  12  Budget Sales    4248 non-null   int64
#  13  COGS            4248 non-null   int64
#  14  Inventory       4248 non-null   int64
#  15  Margin          4248 non-null   int64
#  16  Marketing       4248 non-null   int64
# ...

# %%
df[(df['Budget Sales']>100) & (df['Budget Profit']>50)]
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# 5         720.0  40909  Central  Major Market     Decaf Espresso        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4231      503.0  41609     West  Small Market              Lemon       Leaves
# 4234      971.0  41609     West  Small Market     Decaf Espresso        Beans
# 4241      253.0  41609     West  Small Market          Chamomile       Leaves
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
#
# ...

# %%
df[(df['Budget Profit']>50)]
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# 5         720.0  40909  Central  Major Market     Decaf Espresso        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4231      503.0  41609     West  Small Market              Lemon       Leaves
# 4234      971.0  41609     West  Small Market     Decaf Espresso        Beans
# 4241      253.0  41609     West  Small Market          Chamomile       Leaves
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
#
# ...

# %%
dict = { 'bedrooms' : (9,5,7,56),
         'floors' : (55,33,335,20),
         'Profit' : (10,20,220,33)
       }
dict
# Out:
# {'bedrooms': (9, 5, 7, 56),
#  'floors': (55, 33, 335, 20),
#  'Profit': (10, 20, 220, 33)}

# %%
df1 = pd.DataFrame(dict)
df1
# Out:
#    bedrooms  floors  Profit
# 0         9      55      10
# 1         5      33      20
# 2         7     335     220
# 3        56      20      33

# %%
df2 = pd.merge(df,df1, on='Profit' , how='outer')

# %%
df2
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         646.0  40909     East  Major Market          Earl Grey       Leaves
# 2         619.0  40909     West  Major Market         Darjeeling       Leaves
# 3         702.0  40940     West  Small Market               Mint       Leaves
# 4         719.0  40969  Central  Major Market          Chamomile       Leaves
# ...         ...    ...      ...           ...                ...          ...
# 4243      530.0  41609     West  Major Market          Colombian        Beans
# 4244      409.0  41609    South  Major Market          Colombian        Beans
# 4245      661.0  41609     West  Major Market              Lemon       Leaves
# 4246      951.0  41609     West  Major Market  Decaf Irish Cream        Beans
# 4247      775.0  41609     West  Small Market          Green Tea       Leaves
#
# ...

# %%
df1
# Out:
#    bedrooms  floors  Profit
# 0         9      55      10
# 1         5      33      20
# 2         7     335     220
# 3        56      20      33

# %%
df1=df1.rename(columns={'floors' :'hhh'})

# %%
df1
# Out:
#    bedrooms  hhh  Profit
# 0         9   55      10
# 1         5   33      20
# 2         7  335     220
# 3        56   20      33

# %%
df1.drop('floors',axis=1)
# Out:
#    bedrooms  Profit
# 0         9      10
# 1         5      20
# 2         7     220
# 3        56      33

# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 0           NaN  40909  Central  Major Market           Amaretto        Beans
# 1         970.0  40909  Central  Major Market          Colombian        Beans
# 2         970.0  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3         303.0  40909  Central  Major Market          Green Tea       Leaves
# 4         303.0  40909  Central  Major Market        Caffe Mocha        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4243      206.0  41609     West  Small Market        Caffe Latte        Beans
# 4244      509.0  41609     West  Small Market        Caffe Mocha        Beans
# 4245      360.0  41609     West  Small Market     Decaf Espresso        Beans
# 4246      360.0  41609     West  Small Market          Colombian        Beans
# 4247      206.0  41609     West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %% [markdown]
# # BarGraph

# %%
mt = df['Market'].value_counts()
mt
# Out:
# Central    1344
# West       1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.bar(mt.index, mt.values, color='pink')
plt.grid()
plt.xlabel('Market')
plt.ylabel('Counts')
plt.title('Market Types vs Its Counts')
plt.show()

# %% [markdown]
# # Line Graph

# %%
plt.figure(figsize=(10,15))
plt.plot(mt.index , mt.values, color='blue' , marker='+')
plt.grid()
plt.xlabel('Market')
plt.ylabel('Counts')
plt.title('Market Types vs Its Counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (15,15))
plt.pie(mt, labels = mt.index, autopct= '%.2f%%')
plt.legend(loc=1)
plt.title('Market and its counts')
plt.show()

# %% [markdown]
# # Scatter Chart

# %%
df.groupby('Market')['Profit'].sum()
# Out:
# Market
# Central    93852
# East       59217
# South      32478
# West       73996
# Name: Profit, dtype: int64

# %%
p = df[df['Product'] == 'Green Tea']
plt.figure(figsize=(15,15))
plt.scatter(p['Sales'], p['Profit'], color='red', marker='+')
plt.grid()
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # Histogram

# %%
te = df['Total Expenses']
plt.figure(figsize=(15,15))
plt.hist(te, color='green')
plt.grid()
plt.show()

# %% [markdown]
# # Bar and Line Chart.

# %%
plt.figure(figsize=(10,10))
plt.bar(mt.index, mt.values, color='pink')
plt.plot(mt.index , mt.values, color='blue' , marker='+')
plt.grid()
plt.xlabel('Market')
plt.ylabel('Counts')
plt.title('Market Types vs Its Counts')
plt.xticks(rotation = 90)
plt.show()
